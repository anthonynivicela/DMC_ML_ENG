# %%
import pandas as pd 
from pycaret.regression  import *

# %%
#1 Cargamos la data
df= pd.read_csv('ds_credito_vehicular.csv')

# %%
df.head()
# Out:
#    edad  ingresos_mensuales estado_civil historia_credito  \
# 0    59                7668   Divorciado            Buena
# 1    49                6279       Casado            Buena
# 2    35                2722      Soltero             Mala
# 3    63                4314   Divorciado          Regular
# 4    28                4157      Soltero            Buena
#
#    nro_creditos_previos  cuota_vs_ingreso  vehiculo_propio  default
# 0                     2              0.64                0        1
# 1                     2              0.31                1        1
# 2                     4              0.41                1        0
# 3                     4              0.57                0        0
# 4                     1              0.34                0        0

# %%
reg=setup(data=df, target='default', session_id=123,normalize=True, categorical_features=['estado_civil','historia_credito'])
# Out:
# <style type="text/css">
# #T_69206_row9_col1, #T_69206_row15_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_69206">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_69206_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_69206_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_69206_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_69206_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_69206_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_69206_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_69206_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_69206_row1_col1" class="data row1 col1" >default</td>
#     </tr>
#     <tr>
#       <th id="T_69206_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_bf39a th {
#   text-align: left;
# }
# ...

# %%
lasso=create_model('llar')
# Out:
# <style type="text/css">
# #T_cb164_row10_col0, #T_cb164_row10_col1, #T_cb164_row10_col2, #T_cb164_row10_col3, #T_cb164_row10_col4, #T_cb164_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_cb164">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb164_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_cb164_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_cb164_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_cb164_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_cb164_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_cb164_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
tuned_lasso = tune_model(lasso)
# Out:
# <style type="text/css">
# #T_09dae_row10_col0, #T_09dae_row10_col1, #T_09dae_row10_col2, #T_09dae_row10_col3, #T_09dae_row10_col4, #T_09dae_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_09dae">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_09dae_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_09dae_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_09dae_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_09dae_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_09dae_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_09dae_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
evaluate_model(tuned_lasso)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
predicciones = predict_model(tuned_lasso)
print(predicciones.head())
# Out:
# <style type="text/css">
# </style>
# <table id="T_b1933">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b1933_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_b1933_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_b1933_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_b1933_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_b1933_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_b1933_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_b1933_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b1933_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b1933_row0_col0" class="data row0 col0" >Lasso Least Angle Regression</td>
#       <td id="T_b1933_row0_col1" class="data row0 col1" >0.2821</td>
# ...

# %%
save_model(tuned_lasso,'modelo_final_lasso')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['edad', 'ingresos_mensuales',
#                                               'nro_creditos_previos',
#                                               'cuota_vs_ingreso',
#                                               'vehiculo_propio'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
#                                                                strategy='mean'))),
# ...
