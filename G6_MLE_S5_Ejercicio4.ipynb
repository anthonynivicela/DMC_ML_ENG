# %%
import pandas as pd
from pycaret.classification import *
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# 1. Cargar datos
df = pd.read_csv("caso4_salud_enfermedades.csv")

# %%
df
# Out:
#      edad   imc  fuma ejercicio_frecuencia  ingesta_azucar  enfermedad_cronica
# 0      61  21.5     0                Nunca           137.0                   0
# 1      46  18.0     0                Nunca            72.8                   0
# 2      56  32.9     1            1-2 veces           131.9                   0
# 3      26  36.0     1             3+ veces            96.9                   0
# 4      67  29.3     0            1-2 veces           116.6                   0
# ..    ...   ...   ...                  ...             ...                 ...
# 195    43  31.1     1            1-2 veces            95.1                   0
# 196    66  35.4     0                Nunca            43.5                   0
# 197    31  31.5     0                Nunca           146.8                   0
# 198    41  18.9     1            1-2 veces           136.8                   0
# 199    44  31.6     0             3+ veces           117.8                   0
#
# [200 rows x 6 columns]

# %%
# 2. Feature Engineering sofisticado
df['obesidad'] = (df['imc'] > 30).astype(int)
df['azucar_alta'] = (df['ingesta_azucar'] > 100).astype(int)

# Variable ordinal para ejercicio
orden_ejercicio = {'Nunca': 0, '1-2 veces': 1, '3+ veces': 2}
df['ejercicio_freq_num'] = df['ejercicio_frecuencia'].map(orden_ejercicio)

# Interacción no lineal que suele indicar riesgo metabólico
df['riesgo_metabolico'] = df['imc'] * df['ingesta_azucar'] * (1 - df['ejercicio_freq_num'])

# Clasificación basada en KMeans (estrategia semi no supervisada para clusterizar riesgo)
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

X_cluster = df[['imc', 'ingesta_azucar', 'edad']]
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_cluster)
kmeans = KMeans(n_clusters=3, random_state=42)
df['cluster_riesgo'] = kmeans.fit_predict(X_scaled)

# %%
print(df.columns)
# Out:
# Index(['edad', 'imc', 'fuma', 'ejercicio_frecuencia', 'ingesta_azucar',
#        'enfermedad_cronica', 'obesidad', 'azucar_alta', 'ejercicio_freq_num',
#        'riesgo_metabolico', 'cluster_riesgo'],
#       dtype='object')

# %%
# 3. Configurar PyCaret con todo el nuevo feature engineering
clf = setup(data=df,
            target='enfermedad_cronica',
            session_id=777,
            ignore_features=['ejercicio_frecuencia'],
            categorical_features=['cluster_riesgo'],
            bin_numeric_features=['edad', 'ingesta_azucar', 'riesgo_metabolico'],
            feature_selection=True,
            remove_multicollinearity=True,
            multicollinearity_threshold=0.8,
             fix_imbalance=True
           )
# Out:
# [LightGBM] [Info] Number of positive: 29, number of negative: 111
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000051 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 25
# [LightGBM] [Info] Number of data points in the train set: 140, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.207143 -> initscore=-1.342234
# [LightGBM] [Info] Start training from score -1.342234
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# <style type="text/css">
# #T_2e492_row10_col1, #T_2e492_row16_col1, #T_2e492_row18_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_2e492">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2e492_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_2e492_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e492_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2e492_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_2e492_row0_col1" class="data row0 col1" >777</td>
#     </tr>
#     <tr>
#       <th id="T_2e492_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2e492_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_2e492_row1_col1" class="data row1 col1" >enfermedad_cronica</td>
#     </tr>
#     <tr>
#       <th id="T_2e492_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2e492_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_2e492_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_2e492_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2e492_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_2e492_row3_col1" class="data row3 col1" >(200, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_2e492_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2e492_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_2e492_row4_col1" class="data row4 col1" >(200, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_2e492_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2e492_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_2e492_row5_col1" class="data row5 col1" >(140, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_2e492_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2e492_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_2e492_row6_col1" class="data row6 col1" >(60, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_2e492_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2e492_row7_col0" class="data row7 col0" >Ignore features</td>
#       <td id="T_2e492_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_2e492_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2e492_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_2e492_row8_col1" class="data row8 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_2e492_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2e492_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_2e492_row9_col1" class="data row9 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_2e492_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_2e492_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_2e492_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2e492_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_2e492_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_2e492_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_2e492_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_2e492_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_2e492_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_2e492_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_2e492_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_2e492_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_2e492_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_2e492_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_2e492_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_2e492_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_2e492_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_2e492_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_2e492_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_2e492_row16_col0" class="data row16 col0" >Remove multicollinearity</td>
#       <td id="T_2e492_row16_col1" class="data row16 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2e492_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_2e492_row17_col0" class="data row17 col0" >Multicollinearity threshold</td>
#       <td id="T_2e492_row17_col1" class="data row17 col1" >0.800000</td>
#     </tr>
#     <tr>
#       <th id="T_2e492_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_2e492_row18_col0" class="data row18 col0" >Feature selection</td>
#       <td id="T_2e492_row18_col1" class="data row18 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2e492_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_2e492_row19_col0" class="data row19 col0" >Feature selection method</td>
#       <td id="T_2e492_row19_col1" class="data row19 col1" >classic</td>
#     </tr>
#     <tr>
#       <th id="T_2e492_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_2e492_row20_col0" class="data row20 col0" >Feature selection estimator</td>
#       <td id="T_2e492_row20_col1" class="data row20 col1" >lightgbm</td>
#     </tr>
#     <tr>
#       <th id="T_2e492_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_2e492_row21_col0" class="data row21 col0" >Number of features selected</td>
#       <td id="T_2e492_row21_col1" class="data row21 col1" >0.200000</td>
#     </tr>
#     <tr>
#       <th id="T_2e492_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_2e492_row22_col0" class="data row22 col0" >Fold Generator</td>
#       <td id="T_2e492_row22_col1" class="data row22 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_2e492_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_2e492_row23_col0" class="data row23 col0" >Fold Number</td>
#       <td id="T_2e492_row23_col1" class="data row23 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_2e492_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_2e492_row24_col0" class="data row24 col0" >CPU Jobs</td>
#       <td id="T_2e492_row24_col1" class="data row24 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_2e492_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_2e492_row25_col0" class="data row25 col0" >Use GPU</td>
#       <td id="T_2e492_row25_col1" class="data row25 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2e492_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_2e492_row26_col0" class="data row26 col0" >Log Experiment</td>
#       <td id="T_2e492_row26_col1" class="data row26 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2e492_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_2e492_row27_col0" class="data row27 col0" >Experiment Name</td>
#       <td id="T_2e492_row27_col1" class="data row27 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_2e492_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_2e492_row28_col0" class="data row28 col0" >USI</td>
#       <td id="T_2e492_row28_col1" class="data row28 col1" >418f</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 4. Comparar modelos optimizando por AUC (curva ROC balanceada)
best_model = compare_models(sort='AUC')
# Out:
# <style type="text/css">
# #T_f5b0e th {
#   text-align: left;
# }
# #T_f5b0e_row0_col0, #T_f5b0e_row0_col3, #T_f5b0e_row0_col4, #T_f5b0e_row0_col5, #T_f5b0e_row0_col6, #T_f5b0e_row0_col7, #T_f5b0e_row1_col0, #T_f5b0e_row1_col3, #T_f5b0e_row1_col4, #T_f5b0e_row1_col5, #T_f5b0e_row1_col6, #T_f5b0e_row1_col7, #T_f5b0e_row2_col0, #T_f5b0e_row2_col3, #T_f5b0e_row2_col4, #T_f5b0e_row2_col5, #T_f5b0e_row2_col6, #T_f5b0e_row2_col7, #T_f5b0e_row3_col0, #T_f5b0e_row3_col3, #T_f5b0e_row3_col4, #T_f5b0e_row3_col5, #T_f5b0e_row3_col6, #T_f5b0e_row3_col7, #T_f5b0e_row4_col0, #T_f5b0e_row4_col3, #T_f5b0e_row4_col4, #T_f5b0e_row4_col5, #T_f5b0e_row4_col6, #T_f5b0e_row4_col7, #T_f5b0e_row5_col0, #T_f5b0e_row5_col2, #T_f5b0e_row5_col3, #T_f5b0e_row5_col4, #T_f5b0e_row5_col5, #T_f5b0e_row5_col6, #T_f5b0e_row5_col7, #T_f5b0e_row6_col0, #T_f5b0e_row6_col2, #T_f5b0e_row6_col3, #T_f5b0e_row6_col4, #T_f5b0e_row6_col5, #T_f5b0e_row6_col6, #T_f5b0e_row6_col7, #T_f5b0e_row7_col0, #T_f5b0e_row7_col2, #T_f5b0e_row7_col3, #T_f5b0e_row7_col4, #T_f5b0e_row7_col5, #T_f5b0e_row7_col6, #T_f5b0e_row7_col7, #T_f5b0e_row8_col0, #T_f5b0e_row8_col2, #T_f5b0e_row8_col3, #T_f5b0e_row8_col4, #T_f5b0e_row8_col5, #T_f5b0e_row8_col6, #T_f5b0e_row8_col7, #T_f5b0e_row9_col0, #T_f5b0e_row9_col2, #T_f5b0e_row9_col3, #T_f5b0e_row9_col4, #T_f5b0e_row9_col5, #T_f5b0e_row9_col6, #T_f5b0e_row9_col7, #T_f5b0e_row10_col0, #T_f5b0e_row10_col2, #T_f5b0e_row10_col3, #T_f5b0e_row10_col4, #T_f5b0e_row10_col5, #T_f5b0e_row10_col6, #T_f5b0e_row10_col7, #T_f5b0e_row11_col0, #T_f5b0e_row11_col2, #T_f5b0e_row11_col3, #T_f5b0e_row11_col4, #T_f5b0e_row11_col5, #T_f5b0e_row11_col6, #T_f5b0e_row11_col7, #T_f5b0e_row12_col0, #T_f5b0e_row12_col1, #T_f5b0e_row12_col2, #T_f5b0e_row12_col6, #T_f5b0e_row12_col7, #T_f5b0e_row13_col0, #T_f5b0e_row13_col2, #T_f5b0e_row13_col3, #T_f5b0e_row13_col4, #T_f5b0e_row13_col5 {
#   text-align: left;
# }
# #T_f5b0e_row0_col1, #T_f5b0e_row0_col2, #T_f5b0e_row1_col1, #T_f5b0e_row1_col2, #T_f5b0e_row2_col1, #T_f5b0e_row2_col2, #T_f5b0e_row3_col1, #T_f5b0e_row3_col2, #T_f5b0e_row4_col1, #T_f5b0e_row4_col2, #T_f5b0e_row5_col1, #T_f5b0e_row6_col1, #T_f5b0e_row7_col1, #T_f5b0e_row8_col1, #T_f5b0e_row9_col1, #T_f5b0e_row10_col1, #T_f5b0e_row11_col1, #T_f5b0e_row12_col3, #T_f5b0e_row12_col4, #T_f5b0e_row12_col5, #T_f5b0e_row13_col1, #T_f5b0e_row13_col6, #T_f5b0e_row13_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_f5b0e_row0_col8, #T_f5b0e_row1_col8, #T_f5b0e_row2_col8, #T_f5b0e_row3_col8, #T_f5b0e_row4_col8, #T_f5b0e_row5_col8, #T_f5b0e_row6_col8, #T_f5b0e_row7_col8, #T_f5b0e_row8_col8, #T_f5b0e_row9_col8, #T_f5b0e_row10_col8, #T_f5b0e_row11_col8, #T_f5b0e_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_f5b0e_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_f5b0e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f5b0e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f5b0e_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_f5b0e_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_f5b0e_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_f5b0e_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_f5b0e_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_f5b0e_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_f5b0e_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_f5b0e_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f5b0e_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_f5b0e_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_f5b0e_row0_col1" class="data row0 col1" >0.7929</td>
#       <td id="T_f5b0e_row0_col2" class="data row0 col2" >0.5519</td>
#       <td id="T_f5b0e_row0_col3" class="data row0 col3" >0.0000</td>
#       <td id="T_f5b0e_row0_col4" class="data row0 col4" >0.0000</td>
#       <td id="T_f5b0e_row0_col5" class="data row0 col5" >0.0000</td>
#       <td id="T_f5b0e_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_f5b0e_row0_col7" class="data row0 col7" >0.0000</td>
#       <td id="T_f5b0e_row0_col8" class="data row0 col8" >1.2080</td>
#     </tr>
#     <tr>
#       <th id="T_f5b0e_level0_row1" class="row_heading level0 row1" >nb</th>
#       <td id="T_f5b0e_row1_col0" class="data row1 col0" >Naive Bayes</td>
#       <td id="T_f5b0e_row1_col1" class="data row1 col1" >0.7929</td>
#       <td id="T_f5b0e_row1_col2" class="data row1 col2" >0.5519</td>
#       <td id="T_f5b0e_row1_col3" class="data row1 col3" >0.0000</td>
#       <td id="T_f5b0e_row1_col4" class="data row1 col4" >0.0000</td>
#       <td id="T_f5b0e_row1_col5" class="data row1 col5" >0.0000</td>
#       <td id="T_f5b0e_row1_col6" class="data row1 col6" >0.0000</td>
#       <td id="T_f5b0e_row1_col7" class="data row1 col7" >0.0000</td>
#       <td id="T_f5b0e_row1_col8" class="data row1 col8" >0.1100</td>
#     </tr>
#     <tr>
#       <th id="T_f5b0e_level0_row2" class="row_heading level0 row2" >ridge</th>
#       <td id="T_f5b0e_row2_col0" class="data row2 col0" >Ridge Classifier</td>
#       <td id="T_f5b0e_row2_col1" class="data row2 col1" >0.7929</td>
#       <td id="T_f5b0e_row2_col2" class="data row2 col2" >0.5519</td>
#       <td id="T_f5b0e_row2_col3" class="data row2 col3" >0.0000</td>
#       <td id="T_f5b0e_row2_col4" class="data row2 col4" >0.0000</td>
#       <td id="T_f5b0e_row2_col5" class="data row2 col5" >0.0000</td>
#       <td id="T_f5b0e_row2_col6" class="data row2 col6" >0.0000</td>
#       <td id="T_f5b0e_row2_col7" class="data row2 col7" >0.0000</td>
#       <td id="T_f5b0e_row2_col8" class="data row2 col8" >0.0780</td>
#     </tr>
#     <tr>
#       <th id="T_f5b0e_level0_row3" class="row_heading level0 row3" >qda</th>
#       <td id="T_f5b0e_row3_col0" class="data row3 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_f5b0e_row3_col1" class="data row3 col1" >0.7929</td>
#       <td id="T_f5b0e_row3_col2" class="data row3 col2" >0.5519</td>
#       <td id="T_f5b0e_row3_col3" class="data row3 col3" >0.0000</td>
#       <td id="T_f5b0e_row3_col4" class="data row3 col4" >0.0000</td>
#       <td id="T_f5b0e_row3_col5" class="data row3 col5" >0.0000</td>
#       <td id="T_f5b0e_row3_col6" class="data row3 col6" >0.0000</td>
#       <td id="T_f5b0e_row3_col7" class="data row3 col7" >0.0000</td>
#       <td id="T_f5b0e_row3_col8" class="data row3 col8" >0.0800</td>
#     </tr>
#     <tr>
#       <th id="T_f5b0e_level0_row4" class="row_heading level0 row4" >lda</th>
#       <td id="T_f5b0e_row4_col0" class="data row4 col0" >Linear Discriminant Analysis</td>
#       <td id="T_f5b0e_row4_col1" class="data row4 col1" >0.7929</td>
#       <td id="T_f5b0e_row4_col2" class="data row4 col2" >0.5519</td>
#       <td id="T_f5b0e_row4_col3" class="data row4 col3" >0.0000</td>
#       <td id="T_f5b0e_row4_col4" class="data row4 col4" >0.0000</td>
#       <td id="T_f5b0e_row4_col5" class="data row4 col5" >0.0000</td>
#       <td id="T_f5b0e_row4_col6" class="data row4 col6" >0.0000</td>
#       <td id="T_f5b0e_row4_col7" class="data row4 col7" >0.0000</td>
#       <td id="T_f5b0e_row4_col8" class="data row4 col8" >0.0840</td>
#     </tr>
#     <tr>
#       <th id="T_f5b0e_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_f5b0e_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_f5b0e_row5_col1" class="data row5 col1" >0.7929</td>
#       <td id="T_f5b0e_row5_col2" class="data row5 col2" >0.5458</td>
#       <td id="T_f5b0e_row5_col3" class="data row5 col3" >0.0000</td>
#       <td id="T_f5b0e_row5_col4" class="data row5 col4" >0.0000</td>
#       <td id="T_f5b0e_row5_col5" class="data row5 col5" >0.0000</td>
#       <td id="T_f5b0e_row5_col6" class="data row5 col6" >0.0000</td>
#       <td id="T_f5b0e_row5_col7" class="data row5 col7" >0.0000</td>
#       <td i

# %%
# 5. Ajuste fino buscando explicar más sin sobreajuste
tuned = tune_model(best_model, optimize='AUC')
# Out:
# <style type="text/css">
# #T_2271a_row10_col0, #T_2271a_row10_col1, #T_2271a_row10_col2, #T_2271a_row10_col3, #T_2271a_row10_col4, #T_2271a_row10_col5, #T_2271a_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_2271a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2271a_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_2271a_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_2271a_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_2271a_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_2271a_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_2271a_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_2271a_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2271a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2271a_row0_col0" class="data row0 col0" >0.5714</td>
#       <td id="T_2271a_row0_col1" class="data row0 col1" >0.6250</td>
#       <td id="T_2271a_row0_col2" class="data row0 col2" >0.5000</td>
#       <td id="T_2271a_row0_col3" class="data row0 col3" >0.1667</td>
#       <td id="T_2271a_row0_col4" class="data row0 col4" >0.2500</td>
#       <td id="T_2271a_row0_col5" class="data row0 col5" >0.0455</td>
#       <td id="T_2271a_row0_col6" class="data row0 col6" >0.0589</td>
#     </tr>
#     <tr>
#       <th id="T_2271a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2271a_row1_col0" class="data row1 col0" >0.3571</td>
#       <td id="T_2271a_row1_col1" class="data row1 col1" >0.3788</td>
#       <td id="T_2271a_row1_col2" class="data row1 col2" >0.3333</td>
#       <td id="T_2271a_row1_col3" class="data row1 col3" >0.1250</td>
#       <td id="T_2271a_row1_col4" class="data row1 col4" >0.1818</td>
#       <td id="T_2271a_row1_col5" class="data row1 col5" >-0.1887</td>
#       <td id="T_2271a_row1_col6" class="data row1 col6" >-0.2513</td>
#     </tr>
#     <tr>
#       <th id="T_2271a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2271a_row2_col0" class="data row2 col0" >0.2857</td>
#       <td id="T_2271a_row2_col1" class="data row2 col1" >0.3333</td>
#       <td id="T_2271a_row2_col2" class="data row2 col2" >0.3333</td>
#       <td id="T_2271a_row2_col3" class="data row2 col3" >0.1111</td>
#       <td id="T_2271a_row2_col4" class="data row2 col4" >0.1667</td>
#       <td id="T_2271a_row2_col5" class="data row2 col5" >-0.2281</td>
#       <td id="T_2271a_row2_col6" class="data row2 col6" >-0.3373</td>
#     </tr>
#     <tr>
#       <th id="T_2271a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2271a_row3_col0" class="data row3 col0" >0.5714</td>
#       <td id="T_2271a_row3_col1" class="data row3 col1" >0.5303</td>
#       <td id="T_2271a_row3_col2" class="data row3 col2" >0.6667</td>
#       <td id="T_2271a_row3_col3" class="data row3 col3" >0.2857</td>
#       <td id="T_2271a_row3_col4" class="data row3 col4" >0.4000</td>
#       <td id="T_2271a_row3_col5" class="data row3 col5" >0.1429</td>
#       <td id="T_2271a_row3_col6" class="data row3 col6" >0.1741</td>
#     </tr>
#     <tr>
#       <th id="T_2271a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2271a_row4_col0" class="data row4 col0" >0.5714</td>
#       <td id="T_2271a_row4_col1" class="data row4 col1" >0.5606</td>
#       <td id="T_2271a_row4_col2" class="data row4 col2" >0.3333</td>
#       <td id="T_2271a_row4_col3" class="data row4 col3" >0.2000</td>
#       <td id="T_2271a_row4_col4" class="data row4 col4" >0.2500</td>
#       <td id="T_2271a_row4_col5" class="data row4 col5" >-0.0244</td>
#       <td id="T_2271a_row4_col6" class="data row4 col6" >-0.0259</td>
#     </tr>
#     <tr>
#       <th id="T_2271a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2271a_row5_col0" class="data row5 col0" >0.5714</td>
#       <td id="T_2271a_row5_col1" class="data row5 col1" >0.4394</td>
#       <td id="T_2271a_row5_col2" class="data row5 col2" >0.6667</td>
#       <td id="T_2271a_row5_col3" class="data row5 col3" >0.2857</td>
#       <td id="T_2271a_row5_col4" class="data row5 col4" >0.4000</td>
#       <td id="T_2271a_row5_col5" class="data row5 col5" >0.1429</td>
#       <td id="T_2271a_row5_col6" class="data row5 col6" >0.1741</td>
#     </tr>
#     <tr>
#       <th id="T_2271a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2271a_row6_col0" class="data row6 col0" >0.5714</td>
#       <td id="T_2271a_row6_col1" class="data row6 col1" >0.5455</td>
#       <td id="T_2271a_row6_col2" class="data row6 col2" >0.6667</td>
#       <td id="T_2271a_row6_col3" class="data row6 col3" >0.2857</td>
#       <td id="T_2271a_row6_col4" class="data row6 col4" >0.4000</td>
#       <td id="T_2271a_row6_col5" class="data row6 col5" >0.1429</td>
#       <td id="T_2271a_row6_col6" class="data row6 col6" >0.1741</td>
#     </tr>
#     <tr>
#       <th id="T_2271a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2271a_row7_col0" class="data row7 col0" >0.5000</td>
#       <td id="T_2271a_row7_col1" class="data row7 col1" >0.5758</td>
#       <td id="T_2271a_row7_col2" class="data row7 col2" >0.6667</td>
#       <td id="T_2271a_row7_col3" class="data row7 col3" >0.2500</td>
#       <td id="T_2271a_row7_col4" class="data row7 col4" >0.3636</td>
#       <td id="T_2271a_row7_col5" class="data row7 col5" >0.0755</td>
#       <td id="T_2271a_row7_col6" class="data row7 col6" >0.1005</td>
#     </tr>
#     <tr>
#       <th id="T_2271a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2271a_row8_col0" class="data row8 col0" >0.6429</td>
#       <td id="T_2271a_row8_col1" class="data row8 col1" >0.7273</td>
#       <td id="T_2271a_row8_col2" class="data row8 col2" >0.3333</td>
#       <td id="T_2271a_row8_col3" class="data row8 col3" >0.2500</td>
#       <td id="T_2271a_row8_col4" class="data row8 col4" >0.2857</td>
#       <td id="T_2271a_row8_col5" class="data row8 col5" >0.0541</td>
#       <td id="T_2271a_row8_col6" class="data row8 col6" >0.0550</td>
#     </tr>
#     <tr>
#       <th id="T_2271a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2271a_row9_col0" class="data row9 col0" >0.7143</td>
#       <td id="T_2271a_row9_col1" class="data row9 col1" >0.8030</td>
#       <td id="T_2271a_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_2271a_row9_col3" class="data row9 col3" >0.4286</td>
#       <td id="T_2271a_row9_col4" class="data row9 col4" >0.6000</td>
#       <td id="T_2271a_row9_col5" class="data row9 col5" >0.4286</td>
#       <td id="T_2271a_row9_col6" class="data row9 col6" >0.5222</td>
#     </tr>
#     <tr>
#       <th id="T_2271a_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_2271a_row10_col0" class="data row10 col0" >0.5357</td>
#       <td id="T_2271a_row10_col1" class="data row10 col1" >0.5519</td>
#       <td id="T_2271a_row10_col2" class="data row10 col2" >0.5500</td>
#       <td id="T_2271a_row10_col3" class="data row10 col3" >0.2388</td>
#       <td id="T_2271a_row10_col4" class="data row10 col4" >0.3298</td>
#       <td id="T_2271a_row10_col5" class="data row10 col5" >0.0591</td>
#       <td id="T_2271a_row10_col6" class="data row10 col6" >0.0644</td>
#     </tr>
#     <tr>
#       <th id="T_2271a_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_2271a_row11_col0" class="data row11 col0" >0.1206</td>
#       <td id="T_2271a_row11_col1" class="data row11 col1" >0.1381</td>
#       <td id="T_2271a_row11_col2" class="data row11 col2" >0.2115</td>
#       <td id="T_2271a_row11_col3" class="data row11 col3" >0.0888</td>
#       <td id="T_2271a_row1
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
# 6. Interpretación con SHAP (importantísimo en salud)
interpret_model(tuned, plot='summary')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 # 6. Interpretación con SHAP (importantísimo en salud)
# ----> 2 interpret_model(tuned, plot='summary')
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\pycaret\utils\generic.py:964, in check_if_global_is_not_none.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     962     if globals_d[name] is None:
#     963         raise ValueError(message)
# --> 964 return func(*args, **kwargs)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\pycaret\classification\functional.py:1905, in interpret_model(estimator, plot, feature, observation, use_train_data, X_new_sample, y_new_sample, save, **kwargs)
#    1807 @check_if_global_is_not_none(globals(), _CURRENT_EXPERIMENT_DECORATOR_DICT)
#    1808 def interpret_model(
#    1809     estimator,
#    (...)   1817     **kwargs,
#    1818 ):
#    1819     """
#    1820     This function takes a trained model object and returns an interpretation plot
#    1821     based on the test / hold-out set.
#    (...)   1902
#    1903     """
# -> 1905     return _CURRENT_EXPERIMENT.interpret_model(
#    1906         estimator=estimator,
#    1907         plot=plot,
#    1908         feature=feature,
#    1909         observation=observation,
#    1910         use_train_data=use_train_data,
#    1911         X_new_sample=X_new_sample,
#    1912         y_new_sample=y_new_sample,
#    1913         save=save,
#    1914         **kwargs,
#    1915     )
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\pycaret\classification\oop.py:2249, in ClassificationExperiment.interpret_model(self, estimator, plot, feature, observation, use_train_data, X_new_sample, y_new_sample, save, **kwargs)
#    2151 def interpret_model(
#    2152     self,
#    2153     estimator,
#    (...)   2161     **kwargs,
#    2162 ):
#    2163     """
#    2164     This function takes a trained model object and returns an interpretation plot
#    2165     based on the test / hold-out set.
#    (...)   2246
#    2247     """
# -> 2249     return super().interpret_model(
#    2250         estimator=estimator,
#    2251         plot=plot,
#    2252         feature=feature,
#    2253         observation=observation,
#    2254         use_train_data=use_train_data,
#    2255         X_new_sample=X_new_sample,
#    2256         y_new_sample=y_new_sample,
#    2257         save=save,
#    2258         **kwargs,
#    2259     )
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\pycaret\internal\pycaret_experiment\supervised_experiment.py:4083, in _SupervisedExperiment.interpret_model(self, estimator, plot, feature, observation, use_train_data, X_new_sample, y_new_sample, save, **kwargs)
#    4078 shap_models_ids = set(shap_models.keys())
#    4080 if plot in ["summary", "correlation", "reason"] and (
#    4081     model_id not in shap_models_ids
#    4082 ):
# -> 4083     raise TypeError(
#    4084         f"This function only supports tree based models for binary classification: {', '.join(shap_models_ids)}."
#    4085     )
#    4087 # plot type
#    4088 allowed_types = ["summary", "correlation", "reason", "pdp", "msa", "pfi"]
#
# TypeError: This function only supports tree based models for binary classification: et, rf, lightgbm, dt.

# %%
# 7. Crear predicción simulada para una feria de salud
nuevo_caso = pd.DataFrame({
    'edad': [52],
    'imc': [33],
    'fuma': [1],
    'ejercicio_frecuencia': ['Nunca'],
    'ingesta_azucar': [130],
    'obesidad': [1],
    'azucar_alta': [1],
    'ejercicio_freq_num': [0],
    'riesgo_metabolico': [33*130*1],
    'cluster_riesgo': [2]
})
resultado = predict_model(tuned, data=nuevo_caso)
print("Diagnóstico proyectado:", resultado)
# Out:
# Diagnóstico proyectado:    edad  imc  fuma ejercicio_frecuencia  ingesta_azucar  obesidad  \
# 0    52   33     1                Nunca             130         1
#
#    azucar_alta  ejercicio_freq_num  riesgo_metabolico  cluster_riesgo  \
# 0            1                   0               4290               2
#
#    prediction_label  prediction_score
# 0                 0            0.5246

# %%
# 8. Exportar modelo para clínica móvil
save_model(tuned, 'modelo_salud_cronico_movil')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['edad', 'imc', 'fuma',
#                                               'ingesta_azucar', 'obesidad',
#                                               'azucar_alta',
#                                               'ejercicio_freq_num',
#                                               'riesgo_metabolico'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
#                                                                strategy='mean'))),
#                  ('c...
#                                                                  importance_getter='auto',
#                                                                  max_features=1,
#                                                                  norm_order=1,
#                                                                  prefit=False,
#                                                                  threshold=-inf))),
#                  ('trained_model',
#                   LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                      fit_intercept=True, intercept_scaling=1,
#                                      l1_ratio=None, max_iter=1000,
#                                      multi_class='auto', n_jobs=None,
#                                      penalty='l2', random_state=777,
#                                      solver='lbfgs', tol=0.0001, verbose=0,
#                                      warm_start=False))],
#           verbose=False),
#  'modelo_salud_cronico_movil.pkl')
